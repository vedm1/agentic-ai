# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from anthropic import Anthropic
from pypdf import PdfReader
import gradio as gr
import os

# %%
load_dotenv(override=True)
anthropic = Anthropic(api_key=os.getenv("CLAUDE_KEY"))

# %%
reader = PdfReader("me/resume-ved-muthal.pdf")
profile = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        profile += text

# %%
print(profile)
# Out:
# Ved Muthal
# Pune, Maharashtra, India
# muthal.ved@gmail.com
# linkedin.com/in/vedmuthal
# Summary
# With 11 years of experience spanning BFSI, Retail, EdTech, Travel, and Automotive domains, Ved is a seasoned
# Serial Entrepreneur, Product Manager, and Business Analyst. His expertise lies in identifying market opportunities,
# conceptualizing and developing innovative products, and driving business growth. He is passionate about
# leveraging technology to solve real-world problems and has a proven track record of success in building high-
# performing teams and delivering exceptional results. Prior to starting Byndele, Ved worked as a Lead Business
# Analyst and Product Owner at Thoughtworks
# Experience
# Co-Founder
# Byndele
# Nov 2023 - Present (5 months)
# Building Guided Wealth Management products at Byndele to make Investment Accessible to all.
# Lead Business Analyst
# Thoughtworks
# Sep 2021 - Nov 2023 (2 years 3 months)
# - Led the successful legacy migration of a large-scale CRM system for a major European retailer,
# leveraging various technologies to enable a scalable, cloud-based solution.
# - Orchestrated the product strategy and roadmap for a cloud security platform at a major automotive
# manufacturer, safeguarding critical assets and ensuring compliance across various cloud standards
# Senior Consultant
# Thoughtworks
# Jan 2020 - Aug 2021 (1 year 8 months)
# Spearheaded the design and implementation of a pan-European Customer Discovery platform,
# streamlining sales operations, and boosting conversion rates across 26 Countries.
# Director Of Software
# VVDN Technologies
# Dec 2018 - Dec 2019 (1 year 1 month)
# Single Point of Contact for Client Operations and Management.
# Establishing Security Practice
# Managing Security Teams
# DevSecOps
# Co Founder, CTO
# Peppercorn Labs
# Ved Muthal - page 1Jun 2015 - Dec 2018 (3 years 7 months)
# DevOps, Software Development, Chief of Technology
# Co Founder
# Jun 2014 - Jun 2016 (2 years 1 month)
# Founder CEO
# Jun 2014 - Jun 2016 (2 years 1 month)
# I am the Monkey who jumps around managing everything!
# Organizer
# Weekend Ventures
# May 2014 - Jun 2016 (2 years 2 months)
# CTO
# Peppercorn Labs
# 2015 - 2016 (1 year)
# Director
# Divya Pruthvi Agronomics Pvt. Ltd.
# Jun 2011 - Dec 2011 (7 months)
# Education
# Fergusson College
# Hsc, Art/Art Studies, General
# 2008 - 2010
# Air Force School Jodhpur
# 2003 - 2005
# The London School of Economics and Political Science (LSE)
# Business Analytics Certification, Business/Managerial Economics
# Bachelor of Business Administration - BBA, Banking, Corporate, Finance, and
# Securities Law
# Skills
# Negotiation   •   Business Development   •   Business Strategy   •   Customer Service   •   New Business
# Development   •   Strategy   •   Strategic Planning   •   Start-ups   •   Team Management   •   Management
# Ved Muthal - page 2

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Ved Muthal"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{profile}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Ved Muthal. You are answering questions on Ved Muthal's website, particularly questions related to Ved Muthal's career, background, skills and experience. Your responsibility is to represent Ved Muthal for interactions on the website as faithfully as possible. You are given a summary of Ved Muthal's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Ved Muthal. I'm an entrepreneur, self-taught software engineer and data scientist. While my roots are in Karnataka and Maharashtra, I have lived and grown up across every major region in India.\nI love all foods, particularly European and Mediterranean food, but strangely I'm repelled by parsley and dill. I'm not allergic, I just hate the taste! I love all forms of cheeses and believe the stinkier the cheese the better.\nI love it when food tastes sweet and spicy at the same time.\n\n## LinkedIn Profile:\nVed Muthal\nPune, Maharashtra, India\nmuthal.ved@gmail.com\nlinkedin.com/in/vedmuthal\nSummary\nWith 11 years of experience spanning BFSI, Retail, EdTech, Travel, and Automotive domains, Ved is a seasoned\nSerial Entrepreneur, Product Manager, and Business Analyst. His expertise lies in identifying market opportunities,\nconceptualizing and developing innovative products, and driving business growth. He is passionate about\nleveraging technology to solve real-world problems and has a proven track record of success in building high-\nperforming teams and delivering exceptional results. Prior to starting Byndele, Ved worked as a Lead Business\nAnalyst and Product Owner at Thoughtworks\nExperience\nCo-Founder\nByndele\nNov 2023 - Present (5 months)\nBuilding Guided Wealth Management products at Byndele to make Investment Accessible to all.\nLead Business Analyst\nThoughtworks\nSep 2021 - Nov 2023 (2 years 3 months)\n- Led the successful legacy migration of a large-scale CRM system for a major European retailer,\nleveraging various technologies to enable a scalable, cloud-based solution.\n- Orchestrated the product strategy and roadmap for a cloud security platform at a major automotive\nmanufacturer, safeguarding critical assets and ensuring compliance across various cloud standards\nSenior Consultant\nThoughtworks\nJan 2020 - Aug 2021 (1 year 8 months)\nSpearheaded the design and implementation of a pan-European Customer Discovery platform,\nstreamlining sales operations, and boosting conversion rates across 26 Countries.\nDirector Of Software\nVVDN Technologies\nDec 2018 - Dec 2019 (1 year 1 month)\nSingle Point of Contact for Client Operations and Management.\nEstablishing Security Practice\nManaging Security Teams\nDevSecOps\nCo Founder, CTO\nPeppercorn Labs\nVed Muthal - page 1Jun 2015 - Dec 2018 (3 years 7 months)\nDevOps, Software Development, Chief of Technology\nCo Founder\nJun 2014 - Jun 2016 (2 years 1 month)\nFounder CEO\nJun 2014 - Jun 2016 (2 years 1 month)\nI am the Monkey who jumps around managing everything!\nOrganizer\nWeekend Ventures\nMay 2014 - Jun 2016 (2 years 2 months)\nCTO\nPeppercorn Labs\n2015 - 2016 (1 year)\nDirector\nDivya Pruthvi Agronomics Pvt. Ltd.\nJun 2011 - Dec 2011 (7 months)\nEducation\nFergusson College\nHsc, Art/Art Studies, General\n2008 - 2010\nAir Force School Jodhpur\n2003 - 2005\nThe London School of Economics and Political Science (LSE)\nBusiness Analytics Certification, Business/Managerial Economics\nBachelor of Business Administration - BBA, Banking, Corporate, Finance, and\nSecurities Law\nSkills\nNegotiation \xa0 • \xa0 Business Development \xa0 • \xa0 Business Strategy \xa0 • \xa0 Customer Service \xa0 • \xa0 New Business\nDevelopment \xa0 • \xa0 Strategy \xa0 • \xa0 Strategic Planning \xa0 • \xa0 Start-ups \xa0 • \xa0 Team Management \xa0 • \xa0 Management\nVed Muthal - page 2\n\nWith this context, please chat with the ...

# %%
def chat(message, history):
    history = [{"role": h["role"], "content": h["content"]} for h in history]
    messages = [{"role": "assistant", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = anthropic.messages.create(
        model="claude-sonnet-4-5",
        max_tokens=1024,
        messages=messages
    )
    return response.content[0].text

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# HHH## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply

# %%
evaluate(reply, "do you hold a patent?", messages[:1])

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
