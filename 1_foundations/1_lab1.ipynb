# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
claude_api_key = os.getenv('CLAUDE_KEY')

if claude_api_key:
    print(f"Claude API Key exists and begins {claude_api_key[:8]}")
else:
    print("Claude API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# Claude API Key exists and begins sk-ant-a

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from anthropic import Anthropic

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

anthropic = Anthropic(api_key=claude_api_key)

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = anthropic.messages.create(
    model="claude-sonnet-4-5",
    max_tokens=1024,
    messages=messages
)

print(response.content[0].text)
# Out:
# 2+2 = 4

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = anthropic.messages.create(
    model="claude-sonnet-4-5",
    max_tokens=1024,
    messages=messages
)

question = response.content[0].text

print(question)
# Out:
# If a clock's hour and minute hands coincide exactly every 65 minutes (measured by a perfect reference clock), and the clock started correctly at 12:00, what time will the clock show when the reference clock reads 6:00 PM?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = anthropic.messages.create(
    model="claude-sonnet-4-5",
    max_tokens=1024,
    messages=messages
)

answer = response.content[0].text

print(answer)
# Out:
# I need to find what time the faulty clock shows when 6 hours have passed on the reference clock.
#
# **Understanding the faulty clock's rate:**
#
# On a normal clock, the hour and minute hands coincide every 12/11 hours (approximately 65.45 minutes). This is because the minute hand needs to "lap" the hour hand, and it gains 360° - 30° = 330° per hour relative to the hour hand.
#
# If this faulty clock's hands coincide every 65 minutes (by the reference clock), the clock is running fast.
#
# **Finding the rate ratio:**
#
# For a clock running at rate r (relative to normal time):
# - The hands coincide every (12/11)/r hours of reference time
# - We're told this equals 65 minutes = 65/60 hours
#
# So: (12/11)/r = 65/60
#
# Solving for r:
# r = (12/11) × (60/65)
# r = (12 × 60)/(11 × 65)
# r = 720/715
# r = 144/143
#
# **Calculating the faulty clock's time:**
#
# When 6 hours pass on the reference clock, the faulty clock advances:
# 6 × (144/143) = 864/143 hours
#
# Converting to hours and minutes:
# 864/143 = 6 + 6/143 hours
# 6/143 hours = 6/143 × 60 minutes = 360/143 minutes
# 360/143 ≈ 2.517 minutes ≈ 2 minutes 31 seconds
#
# Therefore, the faulty clock will show approximately **6:02:31** (or 6:02 and 31 seconds).
#
# More precisely: **6 hours, 2 minutes, and 30.63 seconds**, which rounds to **6:02:31 PM**.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# I need to find what time the faulty clock shows when 6 hours have passed on the reference clock.
#
# **Understanding the faulty clock's rate:**
#
# On a normal clock, the hour and minute hands coincide every 12/11 hours (approximately 65.45 minutes). This is because the minute hand needs to "lap" the hour hand, and it gains 360° - 30° = 330° per hour relative to the hour hand.
#
# If this faulty clock's hands coincide every 65 minutes (by the reference clock), the clock is running fast.
#
# **Finding the rate ratio:**
#
# For a clock running at rate r (relative to normal time):
# - The hands coincide every (12/11)/r hours of reference time
# - We're told this equals 65 minutes = 65/60 hours
#
# So: (12/11)/r = 65/60
#
# Solving for r:
# r = (12/11) × (60/65)
# r = (12 × 60)/(11 × 65)
# r = 720/715
# r = 144/143
#
# **Calculating the faulty clock's time:**
#
# When 6 hours pass on the reference clock, the faulty clock advances:
# 6 × (144/143) = 864/143 hours
#
# Converting to hours and minutes:
# 864/143 = 6 + 6/143 hours
# 6/143 hours = 6/143 × 60 minutes = 360/143 minutes
# 360/143 ≈ 2.517 minutes ≈ 2 minutes 31 seconds
#
# Therefore, the faulty clock will show approximately **6:02:31** (or 6:02 and 31 seconds).
#
# More precisely: **6 hours, 2 minutes, and 30.63 seconds**, which rounds to **6:02:31 PM**.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area in India that might be worth exploring for an Agentic AI opportunity."}]

# Then make the first call:

response = anthropic.messages.create(
    model="claude-sonnet-4-5",
    max_tokens=1024,
    messages=messages
)

# Then read the business idea:

business_idea = response.content[0].text

# And repeat! In the next message, include the business idea within the message

# %%
print(business_idea)
from IPython.display import Markdown, display

display(Markdown(business_idea))
# Out:
# # Agricultural Input Supply Chain
#
# ## Why This is Promising for Agentic AI in India
#
# **The Problem:**
# India has 150+ million farmers, most with small landholdings (< 2 hectares). They struggle with:
# - Fragmented supply chains for seeds, fertilizers, pesticides
# - Price opacity and exploitation by middlemen
# - Wrong product selection (soil/crop mismatch)
# - Fake/substandard input products
# - Credit access for purchasing inputs
#
# **The Agentic AI Opportunity:**
#
# An AI agent system that acts as a **"Digital Agriculture Input Advisor & Procurement Agent"** for smallholder farmers:
#
# ### What the Agents Would Do:
#
# 1. **Soil & Crop Analysis Agent**: Processes soil test results, weather data, and crop choice to recommend optimal inputs
#
# 2. **Procurement Agent**: Autonomously searches across suppliers, compares prices, verifies authenticity, and negotiates bulk purchases for farmer collectives
#
# 3. **Credit Agent**: Interfaces with banks/fintech APIs to arrange input financing based on crop cycles and farmer profiles
#
# 4. **Quality Verification Agent**: Tracks product authenticity through supply chain, flags counterfeit risks
#
# 5. **Timing Optimization Agent**: Determines optimal purchase and application timing based on weather forecasts and crop stage
#
# ### Why India Specifically:
#
# - **Scale**: Massive addressable market
# - **Digital infrastructure**: UPI, Aadhaar, India Stack enable agent-to-agent transactions
# - **Government support**: PM-KISAN, soil health card programs provide data hooks
# - **WhatsApp penetration**: Simple interface for farmers to interact with agents
# - **Pain is acute**: Input costs are 40-50% of farming expenses
#
# ### Business Model:
# Small commission on transactions + premium features + data insights to input manufacturers
#
# **This combines real economic impact with technical feasibility in India's unique digital ecosystem.**
# # Agricultural Input Supply Chain
#
# ## Why This is Promising for Agentic AI in India
#
# **The Problem:**
# India has 150+ million farmers, most with small landholdings (< 2 hectares). They struggle with:
# - Fragmented supply chains for seeds, fertilizers, pesticides
# - Price opacity and exploitation by middlemen
# - Wrong product selection (soil/crop mismatch)
# - Fake/substandard input products
# - Credit access for purchasing inputs
#
# **The Agentic AI Opportunity:**
#
# An AI agent system that acts as a **"Digital Agriculture Input Advisor & Procurement Agent"** for smallholder farmers:
#
# ### What the Agents Would Do:
#
# 1. **Soil & Crop Analysis Agent**: Processes soil test results, weather data, and crop choice to recommend optimal inputs
#
# 2. **Procurement Agent**: Autonomously searches across suppliers, compares prices, verifies authenticity, and negotiates bulk purchases for farmer collectives
#
# 3. **Credit Agent**: Interfaces with banks/fintech APIs to arrange input financing based on crop cycles and farmer profiles
#
# 4. **Quality Verification Agent**: Tracks product authenticity through supply chain, flags counterfeit risks
#
# 5. **Timing Optimization Agent**: Determines optimal purchase and application timing based on weather forecasts and crop stage
#
# ### Why India Specifically:
#
# - **Scale**: Massive addressable market
# - **Digital infrastructure**: UPI, Aadhaar, India Stack enable agent-to-agent transactions
# - **Government support**: PM-KISAN, soil health card programs provide data hooks
# - **WhatsApp penetration**: Simple interface for farmers to interact with agents
# - **Pain is acute**: Input costs are 40-50% of farming expenses
#
# ### Business Model:
# Small commission on transactions + premium features + data insights to input manufacturers
#
# **This combines real economic impact with technical feasibility in India's unique digital ecosystem.**

# %%
messages = [{"role": "user", "content": f"Present a pain-point in that industry - something challenging that might be ripe for an Agentic solution for {business_idea}"}]

response = anthropic.messages.create(
    model="claude-sonnet-4-5",
    max_tokens=1024,
    messages=messages
)

pain_point = response.content[0].text

# %%
# print(pain_point)
display(Markdown(pain_point))
# Out:
# # Pain Point: **The "Last-Mile Input Logistics Nightmare"**
#
# ## The Specific Problem
#
# **Agricultural inputs have the worst timing sensitivity of almost any product, yet India's rural supply chain is completely unprepared for this.**
#
# ### The Challenge in Detail:
#
# **1. Time-Critical Windows**
# - Farmers need specific inputs within 3-7 day windows (pre-monsoon fertilizer application, pest outbreak response)
# - Missing the window = 20-40% crop yield loss
# - But rural delivery infrastructure operates on 15-30 day timelines
#
# **2. Demand Forecasting Chaos**
# - Suppliers can't predict localized demand (varies by microclimate, pest patterns, crop decisions)
# - Results in simultaneous shortage in Village A and excess inventory 20km away in Village B
# - No real-time demand signaling mechanism exists
#
# **3. Inventory Fragmentation**
# - 400,000+ small retail shops hold inventory
# - No visibility into what's actually available where
# - Farmers waste 2-3 days visiting multiple shops during critical windows
#
# **4. The "Wrong Product" Problem**
# - 30% of purchases are suboptimal choices made in panic
# - Retailer pushes what he has in stock, not what farmer needs
# - By the time farmer realizes, application window is closed
#
# ## Why This is PERFECT for Agentic AI
#
# ### Multi-Agent System Design:
#
# **Demand Sensing Agents (Village Level)**
# - Monitor weather, pest surveillance data, farmer WhatsApp groups
# - Predict input demand 7-14 days ahead with 80%+ accuracy
# - Flag emerging pest/disease outbreaks requiring specific pesticides
#
# **Inventory Intelligence Agents**
# - Real-time tracking of stock across retailer network
# - Predict stockouts before they happen
# - Suggest inventory transfers between nearby retailers
#
# **Routing & Logistics Agents**
# - Optimize last-mile delivery using local transport (tractors, bikes)
# - Coordinate "pooled deliveries" to villages
# - Dynamically reroute based on road conditions (monsoon flooding)
#
# **Farmer Recommendation Agents**
# - "Your soil needs NPK 20:20:10, currently available at Shop A (8km) or can be delivered in 48 hours"
# - Prevent panic purchases of wrong products
#
# **Supply Chain Orchestration Agents**
# - Coordinate between manufacturers, distributors, retailers
# - Trigger pre-positioning of inventory before demand spikes
# - Manage emergency airlifts for critical shortages
#
# ## The Agentic Advantage
#
# **Why traditional software fails here:**
# - Too many variables changing simultaneously
# - Requires autonomous decision-making across organizational boundaries
# - Needs negotiation between agents (retailer inventory agent vs. farmer demand agent)
#
# **Why agents work:**
# - Can operate 24/7 monitoring signals
# - Make micro-decisions without human bottleneck
# - Learn localized patterns (Village X always needs extra urea when Y happens)
# - Coordinate complex logistics autonomously
#
# ## The India-Specific Hook
#
# - **Digital Public Infrastructure**: Integrate with ONDC (Open Network for Digital Commerce) for commerce layer
# - **Bhashini**: Voice agents in local languages for farmer interaction
# - **JAM Trinity**: Aadhaar + bank account for instant payment/credit
# - **Weather data**: IMD APIs for hyperlocal forecasting
# - **Soil health cards**: Government database of 150M+ soil tests
#
# ## Economic Impact
#
# **Current state:**
# - 10-15% yield loss due to input timing failures
# - ₹50,000 crore annual loss to Indian agriculture
#
# **With agentic system:**
# - Reduce timing-related losses by 60-70%
# - ₹30,000+ crore value creation
# - 5-10% increase in farmer income
#
# ## Proof of Concept Path
#
# **Phase 1**: Single district, single crop (cotton in Vidarbha - high pesticide intensity)
# **Phase 2**: Expand to pest-sensitive crops across 5 districts
# **Phase 3**: Add fertilizer logistics optimization
# **Phase 4**: Full input portfolio, national scale
#
# This is a problem where **coordination failure costs billions, involves millions of autonomous actors, and requires real-time decision-making** - the perfect storm for agentic AI.

# %%
print (pain_point)
# Out:
# # Pain Point: **The "Last-Mile Input Logistics Nightmare"**
#
# ## The Specific Problem
#
# **Agricultural inputs have the worst timing sensitivity of almost any product, yet India's rural supply chain is completely unprepared for this.**
#
# ### The Challenge in Detail:
#
# **1. Time-Critical Windows**
# - Farmers need specific inputs within 3-7 day windows (pre-monsoon fertilizer application, pest outbreak response)
# - Missing the window = 20-40% crop yield loss
# - But rural delivery infrastructure operates on 15-30 day timelines
#
# **2. Demand Forecasting Chaos**
# - Suppliers can't predict localized demand (varies by microclimate, pest patterns, crop decisions)
# - Results in simultaneous shortage in Village A and excess inventory 20km away in Village B
# - No real-time demand signaling mechanism exists
#
# **3. Inventory Fragmentation**
# - 400,000+ small retail shops hold inventory
# - No visibility into what's actually available where
# - Farmers waste 2-3 days visiting multiple shops during critical windows
#
# **4. The "Wrong Product" Problem**
# - 30% of purchases are suboptimal choices made in panic
# - Retailer pushes what he has in stock, not what farmer needs
# - By the time farmer realizes, application window is closed
#
# ## Why This is PERFECT for Agentic AI
#
# ### Multi-Agent System Design:
#
# **Demand Sensing Agents (Village Level)**
# - Monitor weather, pest surveillance data, farmer WhatsApp groups
# - Predict input demand 7-14 days ahead with 80%+ accuracy
# - Flag emerging pest/disease outbreaks requiring specific pesticides
#
# **Inventory Intelligence Agents**
# - Real-time tracking of stock across retailer network
# - Predict stockouts before they happen
# - Suggest inventory transfers between nearby retailers
#
# **Routing & Logistics Agents**
# - Optimize last-mile delivery using local transport (tractors, bikes)
# - Coordinate "pooled deliveries" to villages
# - Dynamically reroute based on road conditions (monsoon flooding)
#
# **Farmer Recommendation Agents**
# - "Your soil needs NPK 20:20:10, currently available at Shop A (8km) or can be delivered in 48 hours"
# - Prevent panic purchases of wrong products
#
# **Supply Chain Orchestration Agents**
# - Coordinate between manufacturers, distributors, retailers
# - Trigger pre-positioning of inventory before demand spikes
# - Manage emergency airlifts for critical shortages
#
# ## The Agentic Advantage
#
# **Why traditional software fails here:**
# - Too many variables changing simultaneously
# - Requires autonomous decision-making across organizational boundaries
# - Needs negotiation between agents (retailer inventory agent vs. farmer demand agent)
#
# **Why agents work:**
# - Can operate 24/7 monitoring signals
# - Make micro-decisions without human bottleneck
# - Learn localized patterns (Village X always needs extra urea when Y happens)
# - Coordinate complex logistics autonomously
#
# ## The India-Specific Hook
#
# - **Digital Public Infrastructure**: Integrate with ONDC (Open Network for Digital Commerce) for commerce layer
# - **Bhashini**: Voice agents in local languages for farmer interaction
# - **JAM Trinity**: Aadhaar + bank account for instant payment/credit
# - **Weather data**: IMD APIs for hyperlocal forecasting
# - **Soil health cards**: Government database of 150M+ soil tests
#
# ## Economic Impact
#
# **Current state:**
# - 10-15% yield loss due to input timing failures
# - ₹50,000 crore annual loss to Indian agriculture
#
# **With agentic system:**
# - Reduce timing-related losses by 60-70%
# - ₹30,000+ crore value creation
# - 5-10% increase in farmer income
#
# ## Proof of Concept Path
#
# **Phase 1**: Single district, single crop (cotton in Vidarbha - high pesticide intensity)
# **Phase 2**: Expand to pest-sensitive crops across 5 districts
# **Phase 3**: Add fertilizer logistics optimization
# **Phase 4**: Full input portfolio, national scale
#
# This is a problem where **coordination failure costs billions, involves millions of autonomous actors, and requires real-time decision-making** - the perfect storm for agentic AI.

# %%
messages = [{"role": "user", "content": f"propose the Agentic AI solution for {pain_point}"}]

response = anthropic.messages.create(
    model="claude-sonnet-4-5",
    max_tokens=1024,
    messages=messages
)

solution = response.content[0].text

print(solution)
# Out:
# # Agentic AI Solution: **AgriFlow - Intelligent Last-Mile Input Orchestration System**
#
# ## System Architecture: Multi-Agent Ecosystem
#
# ### **Core Agent Network**
#
# #### **1. HyperLocal Demand Intelligence Agents (Village-DIA)**
# **Deployment:** One agent per gram panchayat (~600,000 agents nationally)
#
# **Data Ingestion:**
# - IMD weather API (real-time + 14-day forecasts)
# - Satellite imagery (ISRO Bhuvan, Sentinel-2 for crop health)
# - Soil Health Card database
# - Local pest surveillance reports (State Agriculture Dept)
# - WhatsApp group scraping (with consent) for farmer chatter
# - Historical purchase patterns from integrated retailers
#
# **Agent Capabilities:**
# - **Predictive modeling:** "In 5 days, this village will need 2.4 tons of NPK 20:20:10"
# - **Outbreak detection:** Identify pest/disease mentions in local conversations → cross-reference with neighboring villages
# - **Crop stage tracking:** Monitor field-level crop development via satellite
# - **Confidence scoring:** Each prediction tagged with reliability percentage
#
# **Output:**
# - Rolling 14-day demand forecasts (updated every 6 hours)
# - Alerts for sudden requirement spikes (pest outbreak, unexpected rain)
#
# ---
#
# #### **2. Retail Inventory Intelligence Agents (Shop-IIA)**
# **Deployment:** One agent per registered retailer (~400,000 agents)
#
# **Integration Methods:**
# - **Tier 1 (Digital shops):** API integration with billing software
# - **Tier 2 (Semi-digital):** Daily SMS-based stock updates parsed by NLP
# - **Tier 3 (Manual):** Voice call agents (Bhashini-powered) for daily stock checks
#
# **Agent Capabilities:**
# - Real-time inventory tracking with expiry date monitoring
# - Predictive stockout alerts: "You'll run out of Urea in 3 days based on current demand"
# - Shelf-life optimization: Flag slow-moving stock for promotional pricing
# - Network visibility: Know what 10 nearest shops have in stock
#
# **Output:**
# - Live inventory map across retail network
# - Transfer recommendations between nearby shops
# - Restocking priorities
#
# ---
#
# #### **3. Logistics Orchestration Agents (Route-LOA)**
# **Deployment:** Regional agents covering 50-100km radius
#
# **Coordination:**
# - Interface with Village-DIA (demand) and Shop-IIA (supply) agents
# - Access to road network data + real-time traffic/weather
# - Integration with local transport network:
#   - Agricultural cooperatives' trucks
#   - Private logistics players
#   - "Uber for tractors" platforms
#   - Two-wheeler delivery fleets
#
# **Agent Capabilities:**
# - **Dynamic routing:** Optimize multi-stop deliveries considering time windows
# - **Capacity pooling:** "Combine orders from 3 farmers in Village X for shared delivery cost"
# - **Monsoon adaptation:** Reroute around flooded roads, suggest alternate modes
# - **Emergency protocols:** Trigger premium logistics for critical time windows
#
# **Output:**
# - Optimized delivery schedules
# - Cost estimates for different delivery speed options
# - Coordination instructions to logistics partners
#
# ---
#
# #### **4. Farmer Advisory Agents (Personal-FAA)**
# **Deployment:** One agent per registered farmer (voice/chat interface)
#
# **Interaction Channels:**
# - WhatsApp chatbot (text + voice notes in 12+ languages via Bhashini)
# - USSD for feature phones
# - Toll-free helpline with AI voice agent
#
# **Agent Capabilities:**
# - **Personalized recommendations:**
#   - "Based on your soil report and current weather, use DAP instead of Urea"
#   - "Wait 2 days for rain before spraying pesticide"
# - **Availability intelligence:**
#   - "Product X available at Shop A (8km) or delivery in 36 hours"
#   - Price comparison across options
# - **Application guidance:** Dosage, timing, safety protocols
# - **Purchase coordination:** Reserve stock, arrange delivery, facilitate payment
#
# **Output:**
# - Conversational guidance for farmers
# - Purchase orders routed to appropriate agents
# - Feedback loop to improve recommendations
#
# ---
#
# #### **5. Supply Chain Coordination Agents (Distributor-SCA)**
# **Deployment:** One agent per distributor/manufacturer hub
#
# **Coordination:**
# - Aggregate demand forecasts from Village
